# %% [markdown]
# # Web Scraping
# ## Largest chemical producers worldwide
# **Author:** Virginia Herrero

# %% [markdown]
# ### Introduction
#
# This project analyzes the largest chemical producers worldwide using data scraped from Wikipedia. The goal is to extract, clean, and visualize industry data to identify key companies, sales figures, and regional trends.
#
# It demonstrates the application of web scraping, data processing, and exploratory data analysis using Python, with a focus on industry insights relevant to chemical engineering and global manufacturing.

# %% [markdown]
# ### Web scraping
#
# Extract the relevant information from Wikipedia.

# %%
# Import all required libraries

from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Specify the url
url = r"https://en.wikipedia.org/wiki/List_of_largest_chemical_producers"

# %%
# Send a GET request to the url
page = requests.get(url)

# %%
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(page.text, "html")

# %%
# Extract the table containing the data needed
table = soup.find("table")

# %%
# Extract the titles of the table
titles = table.find_all("th")

# %%
titles_table = [title.text.strip() for title in titles]
titles_table
# Out:
# ['Rank[4]',
#  'Company',
#  'Chemical sales in 2021USD millions[A]',
#  'Change from 2020in percent',
#  'Headquarters']

# %%
# Create a DataFrame with the scraped titles
df = pd.DataFrame(columns = titles_table)
df
# Out:
# Empty DataFrame
# Columns: [Rank[4], Company, Chemical sales in 2021USD millions[A], Change from 2020in percent, Headquarters]
# Index: []

# %%
# Fill the DataFrame with the scraped values
column_data = table.find_all("tr")

for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %% [markdown]
# **DataFrame with all the data scraped from the Wikipedia website:**

# %%
df
# Out:
#    Rank[4]                    Company Chemical sales in 2021USD millions[A]  \
# 0        1                       BASF                                92,982
# 1        2                    Sinopec                                65,848
# 2        3                        Dow                                54,968
# 3        4                      SABIC                                43,230
# 4        5           Formosa Plastics                                43,173
# 5        6                      Ineos                                39,937
# 6        7                 Petrochina                                39,693
# 7        8  LyondellBasell Industries                                38,995
# 8        9                    LG Chem                                37,257
# 9       10                 ExxonMobil                                36,858
# 10      11  Mitsubishi Chemical Group                                30,719
# 11      12       Hengli Petrochemical                                27,961
# 12      13                      Linde                                27,926
# 13      14                Air Liquide                                27,148
# 14      15                   Syngenta                                24,900
# 15      16        Reliance Industries                                22,583
# 16      17                     Wanhua                                22,561
# 17      18                    Braskem                                19,575
# 18      19          Sumitomo Chemical                                19,176
# 19      20         Shin-Etsu Chemical                                18,885
# 20      21                   Covestro                                18,813
# 21      22           Toray Industries                                17,856
# 22      23          Evonik Industries                                17,692
# 23      24                      Shell                                16,993
# 24      25                     DuPont                                16,653
# 25      26                       Yara                                16,617
# 26      27    Rongsheng Petrochemical                                16,001
# 27      28             Lotte Chemical                                15,827
# 28      29           Mitsui Chemicals                                14,681
# 29      30          Indorama Ventures                                14,626
# 30      31  Chevron Phillips Chemical                                14,104
# 31      32                    Umicore                                13,567
# 32      33                     Solvay                                13,527
# 33      34                      Bayer                                12,743
# 34      35                     Mosaic                                12,357
# 35      36                    Nutrien                                11,590
# 36      37                     Arkema                                11,261
# 37      38                Asahi Kasei                                10,908
# 38      39                        DSM                                10,888
# 39      39           Hanwha Solutions                                10,888
# 40      41           Eastman Chemical                                10,476
# 41      42            Johnson Matthey                                10,412
# 42      43               Air Products                                10,323
# 43      44                   Eurochem                                14,269
# 44      45                   Borealis                                10,164
# 45      46        PTT Global Chemical                                16,521
# 46      47                      Sasol                                 9,011
# 47      48              Tongkun Group                                 8,996
# 48      49                    Lanxess                                 8,940
# 49      50       Hengyi Petrochemical                                 8,858
#
#    Change from 2020in percent                            Headquarters
# 0                       32.9%          Germany, Ludwigshafen am Rhein
# 1                       31.9%                          China, Beijing
# 2                       42.6%        United States, Midland, Michigan
# 3                       50.1%                    Saudi Arabia, Riyadh
# 4                       47.8%                          Taiwan, Taipei
# 5                        121%                  United Kingdom, London
# 6                       41.7%                          China, Beijing
# 7                       66.6%           United States, Houston, Texas
# 8                       41.8%                      South Korea, Seoul
# 9                       59.6%            United States, Spring, Texas
# 10                      24.8%                            Japan, Tokyo
# 11                      31.9%                           China, Suzhou
# 12                      14.5%                         Ireland, Dublin
# 13                      13.4%                           France, Paris
# 14                      20.9%                      Switzerland, Basel
# 15                      65.6%                           India, Mumbai
# 16                      98.2%                           China, Yantai
# 17                      80.4%                       Brazil, São Paulo
# 18                      24.7%                  Japan, Tokyo and Osaka
# 19                      38.6%                            Japan, Tokyo
# 20                      48.5%                     Germany, Leverkusen
# 21                      20.9%                            Japan, Tokyo
# 22                      22.6%                          Germany, Essen
# 23                      45.0%                  United Kingdom, London
# 24                      18.4%     United States, Wilmington, Delaware
# 25                      43.4%                            Norway, Oslo
# 26                      59.6%                         China, Hangzhou
# 27                      48.2%                      South Korea, Seoul
# 28                      33.1%                            Japan, Tokyo
# 29                      41.2%                       Thailand, Bangkok
# 30                      67.1%     United States, The Woodlands, Texas
# 31                      34.4%                       Belgium, Brussels
# 32                      17.7%                       Belgium, Brussels
# 33                       9.7%                     Germany, Leverkusen
# 34                      42.3%      United States, Plymouth, Minnesota
# 35                      62.0%                       Canada, Saskatoon
# 36                      20.7%                        France, Colombes
# 37                      20.9%                            Japan, Tokyo
# 38                      13.5%                    Netherlands, Heerlen
# 39                      22.8%                      South Korea, Seoul
# 40                      23.6%     United States, Kingsport, Tennessee
# 41                      2.48%                  United Kingdom, London
# 42                      16.6%  United States, Allentown, Pennsylvania
# 43                      22.6%                        Switzerland, Zug
# 44                      26.0%                         Austria, Vienna
# 45                      51.7%                       Thailand, Bangkok
# 46                      10.8%              South Africa, Johannesburg
# 47                      28.5%                        China, Tongxiang
# 48                      23.8%                        Germany, Cologne
# 49                      66.8%                         China, Hangzhou

# %%
# Save the scraped dataset
df.to_csv("../data/raw/Scraped-largest-chemical-producers.csv")

# %% [markdown]
# ### Data cleaning
#
# Clean the data scraped from Wikipedia.

# %% [markdown]
# - **View dataset info**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Rank[4]                                50 non-null     object
#  1   Company                                50 non-null     object
#  2   Chemical sales in 2021USD millions[A]  50 non-null     object
#  3   Change from 2020in percent             50 non-null     object
#  4   Headquarters                           50 non-null     object
# dtypes: object(5)
# memory usage: 2.3+ KB

# %%
df.head()
# Out:
#   Rank[4]           Company Chemical sales in 2021USD millions[A]  \
# 0       1              BASF                                92,982
# 1       2           Sinopec                                65,848
# 2       3               Dow                                54,968
# 3       4             SABIC                                43,230
# 4       5  Formosa Plastics                                43,173
#
#   Change from 2020in percent                      Headquarters
# 0                      32.9%    Germany, Ludwigshafen am Rhein
# 1                      31.9%                    China, Beijing
# 2                      42.6%  United States, Midland, Michigan
# 3                      50.1%              Saudi Arabia, Riyadh
# 4                      47.8%                    Taiwan, Taipei

# %%
df.tail()
# Out:
#    Rank[4]               Company Chemical sales in 2021USD millions[A]  \
# 45      46   PTT Global Chemical                                16,521
# 46      47                 Sasol                                 9,011
# 47      48         Tongkun Group                                 8,996
# 48      49               Lanxess                                 8,940
# 49      50  Hengyi Petrochemical                                 8,858
#
#    Change from 2020in percent                Headquarters
# 45                      51.7%           Thailand, Bangkok
# 46                      10.8%  South Africa, Johannesburg
# 47                      28.5%            China, Tongxiang
# 48                      23.8%            Germany, Cologne
# 49                      66.8%             China, Hangzhou

# %% [markdown]
# - **Clean up column names**

# %%
df = df.rename(columns = {"Rank[4]":"Rank", 
                          "Company":"Company", 
                          "Chemical sales in 2021USD millions[A]":"Sales in 2021 in USD millions", 
                          "Change from 2020in percent":"Growth in 2021 in %", 
                          "Headquarters":"Headquarters"})
df
# Out:
#    Rank                    Company Sales in 2021 in USD millions  \
# 0     1                       BASF                        92,982
# 1     2                    Sinopec                        65,848
# 2     3                        Dow                        54,968
# 3     4                      SABIC                        43,230
# 4     5           Formosa Plastics                        43,173
# 5     6                      Ineos                        39,937
# 6     7                 Petrochina                        39,693
# 7     8  LyondellBasell Industries                        38,995
# 8     9                    LG Chem                        37,257
# 9    10                 ExxonMobil                        36,858
# 10   11  Mitsubishi Chemical Group                        30,719
# 11   12       Hengli Petrochemical                        27,961
# 12   13                      Linde                        27,926
# 13   14                Air Liquide                        27,148
# 14   15                   Syngenta                        24,900
# 15   16        Reliance Industries                        22,583
# 16   17                     Wanhua                        22,561
# 17   18                    Braskem                        19,575
# 18   19          Sumitomo Chemical                        19,176
# 19   20         Shin-Etsu Chemical                        18,885
# 20   21                   Covestro                        18,813
# 21   22           Toray Industries                        17,856
# 22   23          Evonik Industries                        17,692
# 23   24                      Shell                        16,993
# 24   25                     DuPont                        16,653
# 25   26                       Yara                        16,617
# 26   27    Rongsheng Petrochemical                        16,001
# 27   28             Lotte Chemical                        15,827
# 28   29           Mitsui Chemicals                        14,681
# 29   30          Indorama Ventures                        14,626
# 30   31  Chevron Phillips Chemical                        14,104
# 31   32                    Umicore                        13,567
# 32   33                     Solvay                        13,527
# 33   34                      Bayer                        12,743
# 34   35                     Mosaic                        12,357
# 35   36                    Nutrien                        11,590
# 36   37                     Arkema                        11,261
# 37   38                Asahi Kasei                        10,908
# 38   39                        DSM                        10,888
# 39   39           Hanwha Solutions                        10,888
# 40   41           Eastman Chemical                        10,476
# 41   42            Johnson Matthey                        10,412
# 42   43               Air Products                        10,323
# 43   44                   Eurochem                        14,269
# 44   45                   Borealis                        10,164
# 45   46        PTT Global Chemical                        16,521
# 46   47                      Sasol                         9,011
# 47   48              Tongkun Group                         8,996
# 48   49                    Lanxess                         8,940
# 49   50       Hengyi Petrochemical                         8,858
#
#    Growth in 2021 in %                            Headquarters
# 0                32.9%          Germany, Ludwigshafen am Rhein
# 1                31.9%                          China, Beijing
# 2                42.6%        United States, Midland, Michigan
# 3                50.1%                    Saudi Arabia, Riyadh
# 4                47.8%                          Taiwan, Taipei
# 5                 121%                  United Kingdom, London
# 6                41.7%                          China, Beijing
# 7                66.6%           United States, Houston, Texas
# 8                41.8%                      South Korea, Seoul
# 9                59.6%            United States, Spring, Texas
# 10               24.8%                            Japan, Tokyo
# 11               31.9%                           China, Suzhou
# 12               14.5%                         Ireland, Dublin
# 13               13.4%                           France, Paris
# 14               20.9%                      Switzerland, Basel
# 15               65.6%                           India, Mumbai
# 16               98.2%                           China, Yantai
# 17               80.4%                       Brazil, São Paulo
# 18               24.7%                  Japan, Tokyo and Osaka
# 19               38.6%                            Japan, Tokyo
# 20               48.5%                     Germany, Leverkusen
# 21               20.9%                            Japan, Tokyo
# 22               22.6%                          Germany, Essen
# 23               45.0%                  United Kingdom, London
# 24               18.4%     United States, Wilmington, Delaware
# 25               43.4%                            Norway, Oslo
# 26               59.6%                         China, Hangzhou
# 27               48.2%                      South Korea, Seoul
# 28               33.1%                            Japan, Tokyo
# 29               41.2%                       Thailand, Bangkok
# 30               67.1%     United States, The Woodlands, Texas
# 31               34.4%                       Belgium, Brussels
# 32               17.7%                       Belgium, Brussels
# 33                9.7%                     Germany, Leverkusen
# 34               42.3%      United States, Plymouth, Minnesota
# 35               62.0%                       Canada, Saskatoon
# 36               20.7%                        France, Colombes
# 37               20.9%                            Japan, Tokyo
# 38               13.5%                    Netherlands, Heerlen
# 39               22.8%                      South Korea, Seoul
# 40               23.6%     United States, Kingsport, Tennessee
# 41               2.48%                  United Kingdom, London
# 42               16.6%  United States, Allentown, Pennsylvania
# 43               22.6%                        Switzerland, Zug
# 44               26.0%                         Austria, Vienna
# 45               51.7%                       Thailand, Bangkok
# 46               10.8%              South Africa, Johannesburg
# 47               28.5%                        China, Tongxiang
# 48               23.8%                        Germany, Cologne
# 49               66.8%                         China, Hangzhou

# %% [markdown]
# - **Clean up numerical values**

# %%
def convert_currency(val):
    """
    Removes comma from string parameter and returns it as an integer
    
    Parameter
    ----------
    val : str
        string value of sales in 2021 in USD millions

    Returns
    -------
    new_val : int
        integer value of sales in 2021 in USD millions
    """
    new_val = val.replace(',','')
    return int(new_val)

# %%
df["Sales in 2021 in USD millions"] = df["Sales in 2021 in USD millions"].apply(convert_currency)

# %%
def convert_percent(val):
    """
    Removes percentage sign from string parameter and returns it as a float round to two decimal places
    
    Parameter
    ----------
    val : str
        string value of growth in 2021 in %

    Returns
    -------
    new_val : int
        float round to two decimal places value of growth in 2021 in %
    """
    new_val = val.replace('%', '')
    return round(float(new_val), 2)

# %%
df["Growth in 2021 in %"] = df["Growth in 2021 in %"].apply(convert_percent)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           50 non-null     object
#  1   Company                        50 non-null     object
#  2   Sales in 2021 in USD millions  50 non-null     int64
#  3   Growth in 2021 in %            50 non-null     float64
#  4   Headquarters                   50 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.3+ KB

# %% [markdown]
# - **Change Data Types**

# %%
df["Rank"] = df["Rank"].astype("int")
df["Sales in 2021 in USD millions"] = df["Sales in 2021 in USD millions"].astype("int")
df["Growth in 2021 in %"] = df["Growth in 2021 in %"].astype("float")

# %% [markdown]
# - **Replacing data that was transfered with errors**

# %%
df["Growth in 2021 in %"] = df["Growth in 2021 in %"].replace(18.4, -18.4)
df["Growth in 2021 in %"] = df["Growth in 2021 in %"].replace(2.48, -2.48)

# %% [markdown]
# - **Check everything is correct**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           50 non-null     int64
#  1   Company                        50 non-null     object
#  2   Sales in 2021 in USD millions  50 non-null     int64
#  3   Growth in 2021 in %            50 non-null     float64
#  4   Headquarters                   50 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.3+ KB

# %% [markdown]
# * **The clean dataset:**

# %%
df
# Out:
#     Rank                    Company  Sales in 2021 in USD millions  \
# 0      1                       BASF                          92982
# 1      2                    Sinopec                          65848
# 2      3                        Dow                          54968
# 3      4                      SABIC                          43230
# 4      5           Formosa Plastics                          43173
# 5      6                      Ineos                          39937
# 6      7                 Petrochina                          39693
# 7      8  LyondellBasell Industries                          38995
# 8      9                    LG Chem                          37257
# 9     10                 ExxonMobil                          36858
# 10    11  Mitsubishi Chemical Group                          30719
# 11    12       Hengli Petrochemical                          27961
# 12    13                      Linde                          27926
# 13    14                Air Liquide                          27148
# 14    15                   Syngenta                          24900
# 15    16        Reliance Industries                          22583
# 16    17                     Wanhua                          22561
# 17    18                    Braskem                          19575
# 18    19          Sumitomo Chemical                          19176
# 19    20         Shin-Etsu Chemical                          18885
# 20    21                   Covestro                          18813
# 21    22           Toray Industries                          17856
# 22    23          Evonik Industries                          17692
# 23    24                      Shell                          16993
# 24    25                     DuPont                          16653
# 25    26                       Yara                          16617
# 26    27    Rongsheng Petrochemical                          16001
# 27    28             Lotte Chemical                          15827
# 28    29           Mitsui Chemicals                          14681
# 29    30          Indorama Ventures                          14626
# 30    31  Chevron Phillips Chemical                          14104
# 31    32                    Umicore                          13567
# 32    33                     Solvay                          13527
# 33    34                      Bayer                          12743
# 34    35                     Mosaic                          12357
# 35    36                    Nutrien                          11590
# 36    37                     Arkema                          11261
# 37    38                Asahi Kasei                          10908
# 38    39                        DSM                          10888
# 39    39           Hanwha Solutions                          10888
# 40    41           Eastman Chemical                          10476
# 41    42            Johnson Matthey                          10412
# 42    43               Air Products                          10323
# 43    44                   Eurochem                          14269
# 44    45                   Borealis                          10164
# 45    46        PTT Global Chemical                          16521
# 46    47                      Sasol                           9011
# 47    48              Tongkun Group                           8996
# 48    49                    Lanxess                           8940
# 49    50       Hengyi Petrochemical                           8858
#
#     Growth in 2021 in %                            Headquarters
# 0                 32.90          Germany, Ludwigshafen am Rhein
# 1                 31.90                          China, Beijing
# 2                 42.60        United States, Midland, Michigan
# 3                 50.10                    Saudi Arabia, Riyadh
# 4                 47.80                          Taiwan, Taipei
# 5                121.00                  United Kingdom, London
# 6                 41.70                          China, Beijing
# 7                 66.60           United States, Houston, Texas
# 8                 41.80                      South Korea, Seoul
# 9                 59.60            United States, Spring, Texas
# 10                24.80                            Japan, Tokyo
# 11                31.90                           China, Suzhou
# 12                14.50                         Ireland, Dublin
# 13                13.40                           France, Paris
# 14                20.90                      Switzerland, Basel
# 15                65.60                           India, Mumbai
# 16                98.20                           China, Yantai
# 17                80.40                       Brazil, São Paulo
# 18                24.70                  Japan, Tokyo and Osaka
# 19                38.60                            Japan, Tokyo
# 20                48.50                     Germany, Leverkusen
# 21                20.90                            Japan, Tokyo
# 22                22.60                          Germany, Essen
# 23                45.00                  United Kingdom, London
# 24               -18.40     United States, Wilmington, Delaware
# 25                43.40                            Norway, Oslo
# 26                59.60                         China, Hangzhou
# 27                48.20                      South Korea, Seoul
# 28                33.10                            Japan, Tokyo
# 29                41.20                       Thailand, Bangkok
# 30                67.10     United States, The Woodlands, Texas
# 31                34.40                       Belgium, Brussels
# 32                17.70                       Belgium, Brussels
# 33                 9.70                     Germany, Leverkusen
# 34                42.30      United States, Plymouth, Minnesota
# 35                62.00                       Canada, Saskatoon
# 36                20.70                        France, Colombes
# 37                20.90                            Japan, Tokyo
# 38                13.50                    Netherlands, Heerlen
# 39                22.80                      South Korea, Seoul
# 40                23.60     United States, Kingsport, Tennessee
# 41                -2.48                  United Kingdom, London
# 42                16.60  United States, Allentown, Pennsylvania
# 43                22.60                        Switzerland, Zug
# 44                26.00                         Austria, Vienna
# 45                51.70                       Thailand, Bangkok
# 46                10.80              South Africa, Johannesburg
# 47                28.50                        China, Tongxiang
# 48                23.80                        Germany, Cologne
# 49                66.80                         China, Hangzhou

# %%
# Save the cleaned dataset
df.to_csv("../data/processed/Largest-chemical-producers-cleaned.csv")

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# - **Null values**

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Rank                             0
# Company                          0
# Sales in 2021 in USD millions    0
# Growth in 2021 in %              0
# Headquarters                     0
# dtype: int64

# %% [markdown]
# - **Duplicates**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - **Outliers**

# %%
outliers = df.drop(columns =["Company", "Rank"]).select_dtypes(include = np.number)
outliers.plot(subplots=True, layout=(4,4), kind = "box", figsize = (12,14), patch_artist = True)
plt.subplots_adjust(wspace = 0.5)

# %% [markdown]
# - **New features: Headquarters column transformation to obtain a Country column**

# %%
headquarters = df["Headquarters"].str.split(", ", expand = True)
headquarters.columns = ["Country", "City", "None"]
df = pd.concat([df, headquarters], axis = 1)
df = df.drop(columns = ["Headquarters", "City", "None"])
df
# Out:
#     Rank                    Company  Sales in 2021 in USD millions  \
# 0      1                       BASF                          92982
# 1      2                    Sinopec                          65848
# 2      3                        Dow                          54968
# 3      4                      SABIC                          43230
# 4      5           Formosa Plastics                          43173
# 5      6                      Ineos                          39937
# 6      7                 Petrochina                          39693
# 7      8  LyondellBasell Industries                          38995
# 8      9                    LG Chem                          37257
# 9     10                 ExxonMobil                          36858
# 10    11  Mitsubishi Chemical Group                          30719
# 11    12       Hengli Petrochemical                          27961
# 12    13                      Linde                          27926
# 13    14                Air Liquide                          27148
# 14    15                   Syngenta                          24900
# 15    16        Reliance Industries                          22583
# 16    17                     Wanhua                          22561
# 17    18                    Braskem                          19575
# 18    19          Sumitomo Chemical                          19176
# 19    20         Shin-Etsu Chemical                          18885
# 20    21                   Covestro                          18813
# 21    22           Toray Industries                          17856
# 22    23          Evonik Industries                          17692
# 23    24                      Shell                          16993
# 24    25                     DuPont                          16653
# 25    26                       Yara                          16617
# 26    27    Rongsheng Petrochemical                          16001
# 27    28             Lotte Chemical                          15827
# 28    29           Mitsui Chemicals                          14681
# 29    30          Indorama Ventures                          14626
# 30    31  Chevron Phillips Chemical                          14104
# 31    32                    Umicore                          13567
# 32    33                     Solvay                          13527
# 33    34                      Bayer                          12743
# 34    35                     Mosaic                          12357
# 35    36                    Nutrien                          11590
# 36    37                     Arkema                          11261
# 37    38                Asahi Kasei                          10908
# 38    39                        DSM                          10888
# 39    39           Hanwha Solutions                          10888
# 40    41           Eastman Chemical                          10476
# 41    42            Johnson Matthey                          10412
# 42    43               Air Products                          10323
# 43    44                   Eurochem                          14269
# 44    45                   Borealis                          10164
# 45    46        PTT Global Chemical                          16521
# 46    47                      Sasol                           9011
# 47    48              Tongkun Group                           8996
# 48    49                    Lanxess                           8940
# 49    50       Hengyi Petrochemical                           8858
#
#     Growth in 2021 in %         Country
# 0                 32.90         Germany
# 1                 31.90           China
# 2                 42.60   United States
# 3                 50.10    Saudi Arabia
# 4                 47.80          Taiwan
# 5                121.00  United Kingdom
# 6                 41.70           China
# 7                 66.60   United States
# 8                 41.80     South Korea
# 9                 59.60   United States
# 10                24.80           Japan
# 11                31.90           China
# 12                14.50         Ireland
# 13                13.40          France
# 14                20.90     Switzerland
# 15                65.60           India
# 16                98.20           China
# 17                80.40          Brazil
# 18                24.70           Japan
# 19                38.60           Japan
# 20                48.50         Germany
# 21                20.90           Japan
# 22                22.60         Germany
# 23                45.00  United Kingdom
# 24               -18.40   United States
# 25                43.40          Norway
# 26                59.60           China
# 27                48.20     South Korea
# 28                33.10           Japan
# 29                41.20        Thailand
# 30                67.10   United States
# 31                34.40         Belgium
# 32                17.70         Belgium
# 33                 9.70         Germany
# 34                42.30   United States
# 35                62.00          Canada
# 36                20.70          France
# 37                20.90           Japan
# 38                13.50     Netherlands
# 39                22.80     South Korea
# 40                23.60   United States
# 41                -2.48  United Kingdom
# 42                16.60   United States
# 43                22.60     Switzerland
# 44                26.00         Austria
# 45                51.70        Thailand
# 46                10.80    South Africa
# 47                28.50           China
# 48                23.80         Germany
# 49                66.80           China

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# - **Sales distribution by company**

# %%
sales_distribution_graph = plt.figure(figsize=(18, 5))
sns.barplot(data = df, x = "Company", y = "Sales in 2021 in USD millions")
plt.grid(color = "b", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Sales in USD millions")
plt.xticks(rotation = 90)
plt.yticks(np.arange(0,100000,5000))
plt.title("Sales distribution by company in 2021", size = 14)
# Out:
# Text(0.5, 1.0, 'Sales distribution by company in 2021')

# %% [markdown]
# - **Top 5 best selling chemical companies in 2021**

# %%
top_5_best_selling_companies_graph = plt.figure(figsize=(18, 5))
sns.barplot(data = df.iloc[0:5], x = "Company", y = "Sales in 2021 in USD millions")
plt.grid(color = "b", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Sales in USD millions")
plt.yticks(np.arange(0,100000,5000))
plt.title("Top 5 best selling chemical companies in 2021", size = 14)
# Out:
# Text(0.5, 1.0, 'Top 5 best selling chemical companies in 2021')

# %% [markdown]
# - **Growth distribution by company**

# %%
growth_df = pd.pivot_table(df, values = ["Growth in 2021 in %", "Country"], index = "Company", aggfunc = "sum")
growth_df = growth_df.reindex(growth_df["Growth in 2021 in %"].sort_values(ascending = False).index)
growth_df
# Out:
#                                   Country  Growth in 2021 in %
# Company
# Ineos                      United Kingdom               121.00
# Wanhua                              China                98.20
# Braskem                            Brazil                80.40
# Chevron Phillips Chemical   United States                67.10
# Hengyi Petrochemical                China                66.80
# LyondellBasell Industries   United States                66.60
# Reliance Industries                 India                65.60
# Nutrien                            Canada                62.00
# ExxonMobil                  United States                59.60
# Rongsheng Petrochemical             China                59.60
# PTT Global Chemical              Thailand                51.70
# SABIC                        Saudi Arabia                50.10
# Covestro                          Germany                48.50
# Lotte Chemical                South Korea                48.20
# Formosa Plastics                   Taiwan                47.80
# Shell                      United Kingdom                45.00
# Yara                               Norway                43.40
# Dow                         United States                42.60
# Mosaic                      United States                42.30
# LG Chem                       South Korea                41.80
# Petrochina                          China                41.70
# Indorama Ventures                Thailand                41.20
# Shin-Etsu Chemical                  Japan                38.60
# Umicore                           Belgium                34.40
# Mitsui Chemicals                    Japan                33.10
# BASF                              Germany                32.90
# Hengli Petrochemical                China                31.90
# Sinopec                             China                31.90
# Tongkun Group                       China                28.50
# Borealis                          Austria                26.00
# Mitsubishi Chemical Group           Japan                24.80
# Sumitomo Chemical                   Japan                24.70
# Lanxess                           Germany                23.80
# Eastman Chemical            United States                23.60
# Hanwha Solutions              South Korea                22.80
# Evonik Industries                 Germany                22.60
# Eurochem                      Switzerland                22.60
# Toray Industries                    Japan                20.90
# Asahi Kasei                         Japan                20.90
# Syngenta                      Switzerland                20.90
# Arkema                             France                20.70
# Solvay                            Belgium                17.70
# Air Products                United States                16.60
# Linde                             Ireland                14.50
# DSM                           Netherlands                13.50
# Air Liquide                        France                13.40
# Sasol                        South Africa                10.80
# Bayer                             Germany                 9.70
# Johnson Matthey            United Kingdom                -2.48
# DuPont                      United States               -18.40

# %%
growth_graph = plt.figure(figsize = (15, 5))
sns.barplot(data = growth_df, x = "Company", y = "Growth in 2021 in %", color = "orange")
plt.grid(color = "orange", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Growth in %")
plt.xticks(rotation = 90)
plt.title("Growth distribution by company in 2021")
# Out:
# Text(0.5, 1.0, 'Growth distribution by company in 2021')

# %% [markdown]
# - **Top 5 fastest growing chemical companies in 2021**

# %%
top_5_fastest_growing_companies_graph = plt.figure(figsize = (15, 5))
sns.barplot(data = growth_df.iloc[0:5], x = "Company", y = "Growth in 2021 in %", palette = "light:orange_r", hue = "Country")
plt.grid(color = "orange", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Growth in %")
plt.title("Top 5 fastest growing chemical companies in 2021")
# Out:
# Text(0.5, 1.0, 'Top 5 fastest growing chemical companies in 2021')

# %% [markdown]
# - **Distribution of the most successful chemical companies by country**

# %%
countries_df = df.groupby("Country")[["Company"]].count().sort_values(by = "Company", ascending = False)
countries_df
# Out:
#                 Company
# Country
# United States         8
# China                 7
# Japan                 6
# Germany               5
# South Korea           3
# United Kingdom        3
# Switzerland           2
# Belgium               2
# Thailand              2
# France                2
# Austria               1
# Brazil                1
# Canada                1
# Netherlands           1
# Ireland               1
# India                 1
# Norway                1
# South Africa          1
# Saudi Arabia          1
# Taiwan                1

# %%
companies_worldwide_graph = plt.figure(figsize = (10, 5))
sns.barplot(data = countries_df, y = "Country", x = "Company", color = "c")
plt.grid(color = "c", linestyle = "-", linewidth = 0.1)
plt.xlabel("Number of companies")
plt.ylabel("Company")
plt.title("Distribution of the most sucessful chemical companies by country", size = 12)
# Out:
# Text(0.5, 1.0, 'Distribution of the most sucessful chemical companies by country')

# %% [markdown]
# ### Analysis of German companies

# %% [markdown]
# - **Top best selling German chemical companies in 2021**

# %%
germany = df[df["Country"] == "Germany"]
germany
# Out:
#     Rank            Company  Sales in 2021 in USD millions  \
# 0      1               BASF                          92982
# 20    21           Covestro                          18813
# 22    23  Evonik Industries                          17692
# 33    34              Bayer                          12743
# 48    49            Lanxess                           8940
#
#     Growth in 2021 in %  Country
# 0                  32.9  Germany
# 20                 48.5  Germany
# 22                 22.6  Germany
# 33                  9.7  Germany
# 48                 23.8  Germany

# %%
german_companies_by_sale_graph = plt.figure(figsize = (10, 5))
sns.barplot(data = germany, x = "Company", y = "Sales in 2021 in USD millions", color = "deeppink")
plt.grid(color = "deeppink", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Sales in USD millions")
plt.title("Top best selling German chemical companies in 2021")
# Out:
# Text(0.5, 1.0, 'Top best selling German chemical companies in 2021')

# %% [markdown]
# - **Top fastest growing German chemical companies in 2021**

# %%
germany_growth_df = germany.sort_values(by = "Growth in 2021 in %", ascending = False)

# %%
german_companies_by_growth_graph = plt.figure(figsize = (10, 5))
ax = sns.barplot(data = germany_growth_df, x = "Company", y = "Growth in 2021 in %", palette = "RdPu_r", hue = "Company")
plt.grid(color = "deeppink", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Growth in %")
plt.title("Top fastest growing German chemical companies in 2021")
for i in ax.containers:
    ax.bar_label(i,)

# %% [markdown]
# ### Conclusions:
#
# #### Top 5 best-selling chemical companies in the world in 2021
# The best performing chemical producing companies in 2021 were:
# * BASF
# * Sinopec
# * Dow
# * SABIC
# * Formosa Plastics

# %%
df.iloc[0:5]
# Out:
#    Rank           Company  Sales in 2021 in USD millions  Growth in 2021 in %  \
# 0     1              BASF                          92982                 32.9
# 1     2           Sinopec                          65848                 31.9
# 2     3               Dow                          54968                 42.6
# 3     4             SABIC                          43230                 50.1
# 4     5  Formosa Plastics                          43173                 47.8
#
#          Country
# 0        Germany
# 1          China
# 2  United States
# 3   Saudi Arabia
# 4         Taiwan

# %%
top_5_best_selling_companies_graph = plt.figure(figsize=(18, 5))
sns.barplot(data = df.iloc[0:5], x = "Company", y = "Sales in 2021 in USD millions")
plt.grid(color = "b", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Sales in USD millions")
plt.yticks(np.arange(0,100000,5000))
plt.title("Top 5 best-selling chemical companies in 2021", size = 14)
# Out:
# Text(0.5, 1.0, 'Top 5 best-selling chemical companies in 2021')

# %% [markdown]
# #### Top 5 fastest growing chemical companies in the world in 2021
# The chemical producing companies that grew the most in the year 2021 were:
# * Ineos
# * Wanhua
# * Braskern
# * Chevron Phillips Chemical
# * Hengyi Petrochemical

# %%
growth_df.iloc[0:5]
# Out:
#                                   Country  Growth in 2021 in %
# Company
# Ineos                      United Kingdom                121.0
# Wanhua                              China                 98.2
# Braskem                            Brazil                 80.4
# Chevron Phillips Chemical   United States                 67.1
# Hengyi Petrochemical                China                 66.8

# %%
top_5_fastest_growing_companies_graph = plt.figure(figsize = (15, 5))
sns.barplot(data = growth_df.iloc[0:5], x = "Company", y = "Growth in 2021 in %", palette = "light:orange_r", hue = "Country")
plt.grid(color = "orange", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Growth in %")
plt.title("Top 5 fastest growing chemical companies in 2021")
# Out:
# Text(0.5, 1.0, 'Top 5 fastest growing chemical companies in 2021')

# %% [markdown]
# #### Global distribution of top-performing chemical companies in 2021
# The United States is the country with the most chemical companies on the list of the world's 50 largest chemical producers, followed by China, Japan and Germany.

# %%
companies_worldwide_graph = plt.figure(figsize = (10, 5))
sns.barplot(data = countries_df, y = "Country", x = "Company", color = "c")
plt.grid(color = "c", linestyle = "-", linewidth = 0.1)
plt.xlabel("Number of companies")
plt.ylabel("Company")
plt.title("Distribution of the most sucessful chemical companies by country", size = 12)
# Out:
# Text(0.5, 1.0, 'Distribution of the most sucessful chemical companies by country')

# %% [markdown]
# #### Top best-selling German chemical companies in 2021
# The German chemical companies that perform the best in the year 2021 were:
# * BASF
# * Covestro
# * Evonik Industries
# * Bayer
# * Lanxess

# %%
germany
# Out:
#     Rank            Company  Sales in 2021 in USD millions  \
# 0      1               BASF                          92982
# 20    21           Covestro                          18813
# 22    23  Evonik Industries                          17692
# 33    34              Bayer                          12743
# 48    49            Lanxess                           8940
#
#     Growth in 2021 in %  Country
# 0                  32.9  Germany
# 20                 48.5  Germany
# 22                 22.6  Germany
# 33                  9.7  Germany
# 48                 23.8  Germany

# %%
german_companies_by_sale_graph = plt.figure(figsize = (10, 5))
sns.barplot(data = germany, x = "Company", y = "Sales in 2021 in USD millions", color = "deeppink")
plt.grid(color = "deeppink", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Sales USD millions")
plt.title("Top best-selling German chemical companies in 2021")
# Out:
# Text(0.5, 1.0, 'Top best-selling German chemical companies in 2021')

# %% [markdown]
# #### Top fastest growing German chemical companies in 2021
# The German chemical producing companies that grew the most in the year 2021 were:
# * Covestro
# * BASF
# * Lanxess
# * Evonik Induestries
# * Bayer

# %%
germany_growth_df
# Out:
#     Rank            Company  Sales in 2021 in USD millions  \
# 20    21           Covestro                          18813
# 0      1               BASF                          92982
# 48    49            Lanxess                           8940
# 22    23  Evonik Industries                          17692
# 33    34              Bayer                          12743
#
#     Growth in 2021 in %  Country
# 20                 48.5  Germany
# 0                  32.9  Germany
# 48                 23.8  Germany
# 22                 22.6  Germany
# 33                  9.7  Germany

# %%
german_companies_by_growth_graph = plt.figure(figsize = (10, 5))
ax = sns.barplot(data = germany_growth_df, x = "Company", y = "Growth in 2021 in %", palette = "RdPu_r", hue = "Company")
plt.grid(color = "deeppink", linestyle = "-", linewidth = 0.1)
plt.xlabel("Company")
plt.ylabel("Growth in %")
plt.title("Top fastest growing German chemical companies in 2021")
for i in ax.containers:
    ax.bar_label(i,)
